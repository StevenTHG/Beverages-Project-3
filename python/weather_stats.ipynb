# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import api_key

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Get latitude and temperature for cities
cities = ['Montgomery', 'Juneau', 'Phoenix', 'Little Rock',	'Sacramento', 'Denver', 'Hartford', 'Dover', 'Honolulu', 'Tallahassee', 'Atlanta',
            'Boise', 'Springfield', 'Indianapolis', 'Des Moines', 'Topeka', 'Frankfort', 'Baton Rouge', 'Augusta', 'Annapolis', 'Boston', 
            'Lansing', 'St. Paul', 'Jackson', 'Jefferson City', 'Helena', 'Lincoln', 'Carson City', 'Concord', 'Trenton', 'Santa Fe', 'Raleigh', 
            'Bismarck', 'Albany', 'Columbus', 'Oklahoma City', 'Salem', 'Harrisburg', 'Providence', 'Columbia', 'Pierre', 'Nashville', 'Austin', 
            'Salt Lake City', 'Montpelier', 'Richmond', 'Olympia', 'Charleston', 'Madison', 'Cheyenne']

# set up lists to hold reponse info
lat = []
lon = []
temp = []
descr = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    lon.append(response['coord']['lon'])
    temp.append(response['main']['temp'])
    descr.append(response['weather'][0]['description'])

# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    'lon': lon,
    "temp": temp,
    'description': descr
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#               city      lat       lon   temp       description
# 0       Montgomery  39.1501  -77.1997   0.73         clear sky
# 1           Juneau  58.3019 -134.4197   1.11        light snow
# 2          Phoenix  33.4484 -112.0740  12.92        few clouds
# 3      Little Rock  34.7465  -92.2896  14.77   overcast clouds
# 4       Sacramento  38.4666 -121.3177  10.05         clear sky
# 5           Denver  39.7392 -104.9847  -0.78     broken clouds
# 6         Hartford  41.7668  -72.7662  -0.80        few clouds
# 7            Dover  39.1582  -75.5244   2.90         clear sky
# 8         Honolulu  21.3069 -157.8583  24.67        few clouds
# 9      Tallahassee  30.4383  -84.2807   9.69              haze
# 10         Atlanta  33.7490  -84.3880   7.96         clear sky
# 11           Boise  43.6135 -116.2035   1.44  scattered clouds
# 12     Springfield  37.2153  -93.2982  14.06  scattered clouds
# 13    Indianapolis  39.7684  -86.1580   5.49   overcast clouds
# 14      Des Moines  41.6005  -93.6091   3.23        few clouds
# 15          Topeka  39.0483  -95.6780   6.03         clear sky
# 16       Frankfort -27.2667   28.4833  12.66     broken clouds
# 17     Baton Rouge  30.4508  -91.1545  13.82         clear sky
# 18         Augusta  48.3667   10.8833  -6.24         clear sky
# 19       Annapolis  38.9785  -76.4922   2.03         clear sky
# 20          Boston  42.3584  -71.0598   0.96  scattered clouds
# 21         Lansing  42.7325  -84.5555  -1.43         clear sky
# 22        St. Paul  44.9444  -93.0933   1.55              mist
# 23         Jackson  42.4165 -122.8345   2.07         clear sky
# 24  Jefferson City  38.5767  -92.1735  16.24   overcast clouds
# 25          Helena  46.5927 -112.0361   3.55     broken clouds
# 26         Lincoln  40.8000  -96.6670   3.57  scattered clouds
# 27     Carson City  39.1638 -119.7674  -1.86         clear sky
# 28         Concord  37.9780 -122.0311   8.85         clear sky
# 29         Trenton  40.2170  -74.7429   1.34         clear sky
# 30        Santa Fe -31.6333  -60.7000  25.73         clear sky
# 31         Raleigh  35.7721  -78.6386   5.05         clear sky
# 32        Bismarck  46.8083 -100.7837  -1.76         clear sky
# 33          Albany  42.6001  -73.9662  -5.49     broken clouds
# 34        Columbus  39.9612  -82.9988   0.16     broken clouds
# 35   Oklahoma City  35.4676  -97.5164  13.91   overcast clouds
# 36           Salem  11.6500   78.1667  25.11              haze
# 37      Harrisburg  40.2737  -76.8844  -0.43         clear sky
# 38      Providence  41.8240  -71.4128   1.20  scattered clouds
# 39        Columbia  34.0007  -81.0348   5.44         clear sky
# 40          Pierre  44.3683 -100.3510   1.61         clear sky
# 41       Nashville  36.1659  -86.7844  10.00  scattered clouds
# 42          Austin  30.2672  -97.7431  18.77   overcast clouds
# 43  Salt Lake City  40.7608 -111.8911  -1.16  scattered clouds
# 44      Montpelier  44.2601  -72.5754 -11.04   overcast clouds
# 45        Richmond  37.5538  -77.4603   1.69         clear sky
# 46         Olympia  47.0379 -122.9007   7.20   overcast clouds
# 47      Charleston  32.7766  -79.9309   8.76         clear sky
# 48         Madison  34.7334  -86.5667   9.79              haze
# 49        Cheyenne  41.1400 -104.8203  -3.42         clear sky
