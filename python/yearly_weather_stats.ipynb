# %%
import pandas as pd

# %%
file_path = r'..\data\WBAN_13996_Topeka_cleaned_yearly.xlsx'
xlsx = pd.ExcelFile(file_path)
df_2013 = pd.read_excel(xlsx, '2013')
df_2014 = pd.read_excel(xlsx, '2014')
df_2015 = pd.read_excel(xlsx, '2015')
df_2016 = pd.read_excel(xlsx, '2016')
df_2017 = pd.read_excel(xlsx, '2017')
df_2018 = pd.read_excel(xlsx, '2018')
df_2019 = pd.read_excel(xlsx, '2019')
df_2020 = pd.read_excel(xlsx, '2020')
df_2021 = pd.read_excel(xlsx, '2021')
df_2022 = pd.read_excel(xlsx, '2022')
df_2023 = pd.read_excel(xlsx, '2023')

# %%
df_2013.head()
# Out:
#        STATION                 DATE REPORT_TYPE  BackupLatitude  \
# 0  72456013996  2013-03-01T23:59:00       SOD           39.0725
# 1  72456013996  2013-03-02T23:59:00       SOD           39.0725
# 2  72456013996  2013-03-03T23:59:00       SOD           39.0725
# 3  72456013996  2013-03-04T23:59:00       SOD           39.0725
# 4  72456013996  2013-03-05T23:59:00       SOD           39.0725
#
#    BackupLongitude       BackupName  DailyAverageDewPointTemperature  \
# 0         -95.6261  TOPEKA ASOS, KS                             19.0
# 1         -95.6261  TOPEKA ASOS, KS                             18.0
# 2         -95.6261  TOPEKA ASOS, KS                             25.0
# 3         -95.6261  TOPEKA ASOS, KS                             31.0
# 4         -95.6261  TOPEKA ASOS, KS                             18.0
#
#   DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 0                             29                          68.0
# ...

# %%
df_2013.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'BackupLatitude', 'BackupLongitude',
#        'BackupName', 'DailyAverageDewPointTemperature',
#        'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity',
#        'DailyAverageSeaLevelPressure', 'DailyAverageStationPressure',
#        'DailyAverageWetBulbTemperature', 'DailyAverageWindSpeed',
#        'DailyCoolingDegreeDays', 'DailyDepartureFromNormalAverageTemperature',
#        'DailyHeatingDegreeDays', 'DailyMaximumDryBulbTemperature',
#        'DailyMinimumDryBulbTemperature', 'DailyPeakWindDirection',
#        'DailyPeakWindSpeed', 'DailyPrecipitation', 'DailySnowDepth',
#        'DailySnowfall', 'DailySustainedWindDirection',
#        'DailySustainedWindSpeed'],
#       dtype='object')

# %%
# df_2013 = df_2013[['STATION','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
# df_2013 = df_2013.replace(72456013996,'Topeka, Kansas')
# df_2013.set_index('STATION')
# df_2013 = df_2013.groupby('STATION').mean()
df_2013.head()
# Out:
#           STATION DailyAverageDryBulbTemperature  \
# 0  Topeka, Kansas                             29
# 1  Topeka, Kansas                             31
# 2  Topeka, Kansas                             36
# 3  Topeka, Kansas                             44
# 4  Topeka, Kansas                             33
#
#   DailyMaximumDryBulbTemperature DailyMinimumDryBulbTemperature
# 0                             31                             27
# 1                             38                             24
# 2                             45                             27
# 3                             53                             35
# 4                             40                             26

# %%
df_2013.mean()
# Out:
# C:\Users\Steven Hoang\AppData\Local\Temp\ipykernel_16040\753267519.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   df_2013.mean()
# Empty DataFrame
# Columns: []
# Index: [Topeka, Kansas]

# %%
df_2014 = df_2014[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2014 = df_2014.replace(72456013996,'Topeka, Kansas')

df_2015 = df_2015[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2015 = df_2015.replace(72456013996,'Topeka, Kansas')

df_2016= df_2016[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2016 = df_2016.replace(72456013996,'Topeka, Kansas')

df_2017 = df_2017[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2017 = df_2017.replace(72456013996,'Topeka, Kansas')

df_2018 = df_2018[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2018 = df_2018.replace(72456013996,'Topeka, Kansas')

df_2019 = df_2019[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2019 = df_2019.replace(72456013996,'Topeka, Kansas')

df_2020 = df_2020[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2020 = df_2020.replace(72456013996,'Topeka, Kansas')

df_2021 = df_2021[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2021 = df_2021.replace(72456013996,'Topeka, Kansas')

df_2022 = df_2022[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2022 = df_2022.replace(72456013996,'Topeka, Kansas')

df_2023 = df_2023[['STATION','DATE','DailyAverageDryBulbTemperature','DailyMaximumDryBulbTemperature','DailyMinimumDryBulbTemperature']]
df_2023 = df_2023.replace(72456013996,'Topeka, Kansas')

# %%
frames = [df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023]
topeka_df = pd.concat(frames)
topeka_df
# Out:
#              STATION                 DATE DailyAverageDryBulbTemperature  \
# 0     Topeka, Kansas  2013-03-01T23:59:00                             29
# 1     Topeka, Kansas  2013-03-02T23:59:00                             31
# 2     Topeka, Kansas  2013-03-03T23:59:00                             36
# 3     Topeka, Kansas  2013-03-04T23:59:00                             44
# 4     Topeka, Kansas  2013-03-05T23:59:00                             33
# ...              ...                  ...                            ...
# 3618  Topeka, Kansas  2023-01-26T23:59:00                             26
# 3619  Topeka, Kansas  2023-01-27T23:59:00                             42
# 3620  Topeka, Kansas  2023-01-28T23:59:00                             37
# 3621  Topeka, Kansas  2023-01-29T23:59:00                             18
# 3622  Topeka, Kansas  2023-01-30T23:59:00                             18
#
#      DailyMaximumDryBulbTemperature DailyMinimumDryBulbTemperature
# ...
