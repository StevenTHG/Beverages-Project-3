# %%
 # Dependencies
import json
import requests
from config import api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39532\699131234.py in <module>
#       2 import json
#       3 import requests
# ----> 4 from config import api_key
#
# ImportError: cannot import name 'api_key' from 'config' (c:\Users\VincentPassanisi\OneDrive - MARISA FOODS\Desktop\uci_bootcamp\16-project3\config.py)

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

# %%
 # Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
#                                                     0  \
# 0    {'unit': 'oz', 'amount': 6, 'ingredient': 'Gin'}
# 1   {'unit': 'oz', 'amount': 4.5, 'ingredient': 'W...
# 2    {'unit': 'oz', 'amount': 3, 'ingredient': 'Gin'}
# 3   {'unit': 'oz', 'amount': 2, 'ingredient': 'Kir...
# 4   {'unit': 'oz', 'amount': 4.5, 'ingredient': 'W...
# 5   {'unit': 'oz', 'amount': 3, 'ingredient': 'Gin...
# 6   {'unit': 'oz', 'amount': 4, 'ingredient': 'Whi...
# 7   {'unit': 'oz', 'amount': 4, 'ingredient': 'Cog...
# 8   {'unit': 'oz', 'amount': 4.5, 'ingredient': 'D...
# 9   {'unit': 'oz', 'amount': 4, 'ingredient': 'Vod...
# 10  {'unit': 'oz', 'amount': 4.5, 'ingredient': 'P...
# 11  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'T...
# 12  {'unit': 'oz', 'amount': 4.5, 'ingredient': 'G...
# 13   {'unit': 'oz', 'amount': 3, 'ingredient': 'Gin'}
# 14  {'unit': 'oz', 'amount': 7.5, 'ingredient': 'C...
# 15  {'unit': 'oz', 'amount': 4.5, 'ingredient': 'W...
# 16  {'unit': 'oz', 'amount': 5, 'ingredient': 'Vod...
# 17  {'unit': 'oz', 'amount': 5, 'ingredient': 'Whi...
# 18  {'unit': 'oz', 'amount': 5, 'ingredient': 'Whi...
# 19  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'C...
#
#                                                     1  \
# 0   {'unit': 'oz', 'amount': 1.5, 'ingredient': 'V...
# 1   {'unit': 'oz', 'amount': 2, 'ingredient': 'Lim...
# 2   {'unit': 'oz', 'amount': 3, 'ingredient': 'Cam...
# 3   {'unit': 'oz', 'amount': 4, 'ingredient': 'Ver...
# 4           {'special': '2 dashes Angostura Bitters'}
# 5   {'unit': 'oz', 'amount': 3, 'ingredient': 'Ver...
# 6   {'unit': 'oz', 'amount': 3, 'ingredient': 'Lim...
# 7   {'unit': 'oz', 'amount': 12, 'ingredient': 'Gi...
# 8   {'unit': 'oz', 'amount': 3.5, 'ingredient': 'O...
# 9   {'unit': 'oz', 'amount': 12, 'ingredient': 'Cr...
# 10  {'unit': 'oz', 'amount': 3, 'ingredient': 'Lem...
# 11  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'V...
# 12  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'S...
# 13  {'unit': 'oz', 'amount': 3, 'ingredient': 'Apr...
# 14  {'unit': 'oz', 'amount': 7.5, 'ingredient': 'O...
# 15  {'unit': 'oz', 'amount': 3.0, 'ingredient': 'L...
# 16  {'unit': 'oz', 'amount': 10, 'ingredient': 'Or...
# 17  {'unit': 'oz', 'amount': 12, 'ingredient': 'Co...
# 18  {'unit': 'oz', 'amount': 2, 'ingredient': 'Ver...
# 19  {'unit': 'oz', 'amount': 4.5, 'ingredient': 'R...
#
#                                                     2  \
# 0   {'unit': 'oz', 'amount': 0.75, 'ingredient': '...
# 1   {'unit': 'oz', 'amount': 1, 'ingredient': 'Syr...
# 2   {'unit': 'oz', 'amount': 3, 'ingredient': 'Ver...
# 3            {'special': '3 dashes Strawberry syrup'}
# 4                         {'special': '1 sugar cube'}
# 5             {'special': '1/2 bar spoon Maraschino'}
# 6                        {'special': '6 Mint sprigs'}
# 7   {'special': 'Dash of Angostura bitters (option...
# 8   {'unit': 'oz', 'amount': 3.5, 'ingredient': 'P...
# 9   {'unit': 'oz', 'amount': 3, 'ingredient': 'Gra...
# 10  {'unit': 'oz', 'amount': 2, 'ingredient': 'Syr...
# 11  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'W...
# 12  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'L...
# 13  {'unit': 'oz', 'amount': 3, 'ingredient': 'Cal...
# 14                                               None
# 15  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'S...
# 16                                               None
# 17  {'unit': 'oz', 'amount': 1, 'ingredient': 'Lim...
# 18            {'special': '1 dash Angostura Bitters'}
# 19  {'unit': 'oz', 'amount': 1, 'ingredient': 'Egg...
#
#                                                     3  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4               {'special': 'Few dashes plain water'}
# 5               {'special': '1/4 bar spoon Absinthe'}
# 6              {'special': '2 teaspoons white sugar'}
# 7                                                None
# 8   {'unit': 'oz', 'amount': 2, 'ingredient': 'Lem...
# 9                                                None
# 10         {'special': '1 raw egg white (small egg)'}
# 11  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'T...
# 12              {'special': 'Few drops of Egg White'}
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                                     4  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5              {'special': '3 dashes Orange Bitters'}
# 6                           {'special': 'Soda water'}
# 7                                                None
# 8   {'unit': 'oz', 'amount': 1, 'ingredient': 'Syr...
# 9                                                None
# 10                                               None
# 11  {'unit': 'oz', 'amount': 1.5, 'ingredient': 'G...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                                     5  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   {'unit': 'oz', 'amount': 1, 'ingredient': 'Syr...
# 9                                                None
# 10                                               None
# 11  {'unit': 'oz', 'amount': 2.5, 'ingredient': 'L...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                                     6  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8      {'special': '3 to 4 dashes Angostura bitters'}
# 9                                                None
# 10                                               None
# 11  {'unit': 'oz', 'amount': 3.0, 'ingredient': 'S...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                 7     8
# 0                            None  None
# 1                            None  None
# 2                            None  None
# 3                            None  None
# 4                            None  None
# 5                            None  None
# 6                            None  None
# 7                            None  None
# 8                            None  None
# 9                            None  None
# 10                           None  None
# 11  {'special': '1 dash of Cola'}  None
# 12                           None  None
# 13                           None  None
# 14                           None  None
# 15                           None  None
# 16                           None  None
# 17                           None  None
# 18                           None  None
# 19                           None  None

# %%
The weather API responded with: {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 277.48, 'pressure': 1026, 'humidity': 86, 'temp_min': 277.15, 'temp_max': 278.15}, 'visibility': 5000, 'wind': {'speed': 2.1, 'deg': 360}, 'clouds': {'all': 90}, 'dt': 1519240800, 'sys': {'type': 1, 'id': 5093, 'message': 0.0062, 'country': 'GB', 'sunrise': 1519196463, 'sunset': 1519234070}, 'id': 2643743, 'name': 'London', 'cod': 200}.
# Out:
# dtype('O')

# %%
# Out:
# object
